# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df_mist = pd.DataFrame({
    'Iteration':[5,5,5,5,5,10,10,10,10,10,15,15,15,15,15,20,20,20,20,20],
    'Precision':[55.38,27.24,28.76,65.26,54.74,54.47,46.45,62.46,55.26,67.74,61.63,51.09,58.74,58.99,65.46,59.55,59.72,54.01,57.05,63.17],
    'Recall':[41.86,40.22,39.02,36.68,45.28,38.95,43.25,38.82,40.31,46.2,30.81,38.84,30.98,35.7,37.56,30.81,34.71,30.39,35.01,33.99],
    'Percentage':[90,80,70,60,50,90,80,70,60,50,90,80,70,60,50,90,80,70,60,50] 
})
df_mist_raw = pd.DataFrame({
    'Iteration':[5,5,5,5,5,10,10,10,10,10,15,15,15,15,15,20,20,20,20,20],
    'Precision':[16.67,4.55,6.25,6.38,1.79,13.33,3.33,5.41,6.25,3.53,20,6.45,9.52,8.06,5.68,20,6.25,8.89,8.2,5.62],
    'Recall':[1.16,0.28,0.39,0.42,0.12,1.16,0.28,0.39,0.56,0.35,1.74,0.55,0.78,0.7,0.58,1.74,0.55,0.78,0.7,0.58],
    'Percentage':[90,80,70,60,50,90,80,70,60,50,90,80,70,60,50,90,80,70,60,50] 
})

sns.set()
sns.set_style("whitegrid")
c_map = sns.diverging_palette(10, 220, sep=32, n=4)

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax = sns.tsplot(time = 'Percentage',value='Recall',unit="Iteration",condition='Iteration',data=df_mist_raw,color=c_map)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax = sns.tsplot(time = 'Percentage',value='Precision',unit="Iteration",condition='Iteration',data=df_mist_raw,color=c_map)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
ax = sns.tsplot(time = 'Percentage',value='Recall',unit="Iteration",condition='Iteration',data=df_mist,color=c_map)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
ax = sns.tsplot(time = 'Percentage',value='Precision',unit="Iteration",condition='Iteration',data=df_mist,color=c_map)
plt.show()
